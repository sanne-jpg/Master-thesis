# %% [markdown]
# ## Running Llama

# %% [markdown]
# ```
# conda deactivate             ## deactivate conda in case you have it active
# venv\Scripts\activate.bat    ## activate your virtual environment
# python -m llama_cpp.server --host 0.0.0.0 --model C:\Users\Sanne\venv\Lib\site-packages\llama_cpp\Meta-Llama-3.1-8B-Instruct.Q4_K_M.gguf --n_ctx 4096   ## lauch the Llama model
# ```

# %% [markdown]
# In case the llama model was no properly exited, run this to still do so. Replace ... with the number the first row returns
# ```
# netstat -ano | findstr :8000
# taskkill /PID ... /F
# ```

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
from collections import defaultdict
from random import sample, seed
from bert_score import score
from llama_cpp import Llama
import utils_llama as ulla
from evaluate import load
from openai import OpenAI
from tqdm import tqdm
import pandas as pd
import numpy as np
import replicate
import random
import pickle
import nltk
import re

# %%
## The dataset created in create_dataset.py 
with open("../Data/all_merged_data.pkl", "rb") as f:
    all_merged_data = pickle.load(f)

# %% [markdown]
# ## Prompting Llama with OpenAI

# %%
## Read in the data
cleaned_data, df_dataset, df_by_gesture_count = ulla.clean_data_for_prompting(all_merged_data)
print(df_dataset)
# Out:
#          file                                           sentence  \
# 0    p15_gold                         all right put a block down
# 1    p15_gold                 put a block one block apart behind
# 2    p15_gold                                                 um
# 3    p15_gold                                     put two blocks
# 4    p15_gold  like about a third of a block a part so more c...
# ..        ...                                                ...
# 241  p42_gold  the first block is like is like like the first...
# 242  p42_gold      and then the second block goes on top of that
# 243  p42_gold                        and it's turned at an angle
# 244  p42_gold                                     no on top yeah
# 245  p42_gold   and then you do that same process all the way up
#
#                                             speech_amr  \
# 0    (p / put-01   :mode imperative   :ARG0 (y / yo...
# 1    (p / put-01   :mode imperative  :ARG0 (y / you...
# 2                           (u / um  :mode expressive)
# 3    (p / put-01  :mode imperative  :ARG0 (y / you)...
# 4    (l / like-04  :ARG2 (q / distance-quantity   :...
# ..                                                 ...
# 241  (s / similar-01  :ARG0 (b / block   :ord (o / ...
# 242  (g / go-01    :ARG1 (b / block     :ord (o / o...
# 243  (t / turn-01   :ARG1 (i / it)            :dest...
# 244  (i / implicate-predicate-00  :mode imperative ...
# 245  (d / do-02    :ARG0 (y / you)    :ARG1 (p / pr...
#
#                                         gesture_labels  \
# 0    [RA: move, front left; RH: into claw, down;, b...
# 1    [LA: move, front, into gap, front; LH: into cl...
# 2        [arms: rotate, gap, left; hands: claw, down;]
# 3    [arms: move, down, gap, left; hands: claw, dow...
# 4    [body: still;, arms: shake, gap, left; hands: ...
# ..                                                 ...
# 241  [body: move, down; hands: into open, down;, ha...
# 242  [RA: move, up;, RA: move, down; RH: into open,...
# 243                     [hands: rotate;, body: still;]
# 244                     [RH: rotate, into open, back;]
# 245  [RH: rotate, into point, left;, RA: rotate, in...
#
#                                           gesture_amrs  num_gesture_amrs
# 0    [(g / gesture-unit  :op1 (i / icon-GA   :ARG0 ...                 1
# 1    [(a / and  :op2 (g / gesture-unit   :op1 (i / ...                 1
# 2    [(a / and  :op1 (g2 / gesture-unit   :op1 (i /...                 1
# 3    [(a / and  :op1 (g2 / gesture-unit   :op1 (i /...                 1
# 4    [(i / icon-GA     :ARG0 (s / signaler)     :AR...                 2
# ..                                                 ...               ...
# 241  [(a / and  :op1 (g / gesture-unit   :op1 (i / ...                 1
# 242  [(a / and  :op1 (g / gesture-unit   :op1 (i / ...                 1
# 243  [(a / and  :op1 (g / gesture-unit   :op1 (i / ...                 1
# 244  [(g / gesture-unit   :op1 (d / deixis-GA    :A...                 1
# 245  [(a / and  :op1 (i / icon-GA   :ARG0 s   :ARG1...                 1
#
# [246 rows x 6 columns]

# %%
## Take 70% of sentences for train set, 30% for test set
df_example_set, df_test_set = ulla.split_data(df_dataset)

## Shuffle the dataframe for later when selecting the prompt examples
np.random.seed(42)
df_example_set = df_example_set.sample(frac=1).reset_index(drop=True)   
print(df_test_set['sentence'][:50])
# Out:
# 0             so put put a block on the back block good
# 1                                        put two blocks
# 2                                                    um
# 3                           and then put one on the top
# 4          no that doesn't look like it’s going to work
# 5                                                   yes
# 6                                      so jiggle the go
# 7                                           good enough
# 8              and then jiggle the two in front of them
# 9                  take another block put it next to it
# 10                                                 okay
# 11                one block on top of each of those two
# 12                                         perfect grab
# 13    and then you’re going to take one of them and ...
# 14                                     only two of them
# 15            place it on the two that are diagonal and
# 16                                       flip those two
# 17                         keep going a little bit more
# 18                   just like that but closer together
# 19                                       doesn't matter
# 20    move those together a little bit closer and th...
# 21                                    put them together
# 22                                   two more blocks up
# 23                                                  yep
# 24                                         go near yeah
# 25                      and uh one block uh ahead of it
# 26                      put one block wherever you want
# 27    the first block you put it the one nearest and...
# 28    we’ll have two blocks ah like apart from each ...
# 29    but that should be on top on top of the of the...
# 30         can you just open it open it a little bit uh
# 31    (unknown) yeah it shouldn’t fall it shouldn’t ...
# 32    then the next row is just three on top of that...
# 33                                 kind of splayed yeah
# 34                                    come evenly there
# 35                                        like an angle
# 36    and it's going to be like a fan or sound wave ...
# 37                               i need four base again
# 38                the next one is three on top of those
# 39    then you're going to put one right next to it ...
# 40                          you're gonna have one block
# 41    there’s gonna be third one that's going to han...
# 42                                           yeah right
# 43    the final one is just pretty much exactly on t...
# 44    same direction that that's pushed off yea alright
# 45                   a block space and on a third block
# 46    then on like the same line you're going to hav...
# 47    over the space in between the blocks so it’ll ...
# 48                                   what one less than
# 49    the other direction it's the same except for t...
# Name: sentence, dtype: object

# %%
## Duplicate each test sentence so that it appears once for every condition --> minimal pairs
## Add prompt types to each sentence
scenarios = ["speech", "gesture", "speech_gesture"]
expanded_rows_test = []
for _, row in df_test_set.iterrows():
    for scenario in scenarios:
        new_row = row.copy()
        new_row["prompt_type"] = scenario

        # Include info according to prompt_type
        if scenario == "speech":
            new_row["gesture_amrs"] = None
            new_row["gesture_labels"] = None
        elif scenario == "gesture":
            new_row["speech_amr"] = None
        expanded_rows_test.append(new_row)

df_test = pd.DataFrame(expanded_rows_test)
df_test["group_id"] = df_test.groupby(["file", "sentence"]).ngroup()
print(df_test[30:40])
# Out:
#         file                                           sentence  \
# 10  p16_gold                                               okay
# 10  p16_gold                                               okay
# 10  p16_gold                                               okay
# 11  p16_gold              one block on top of each of those two
# 11  p16_gold              one block on top of each of those two
# 11  p16_gold              one block on top of each of those two
# 12  p17_gold                                       perfect grab
# 12  p17_gold                                       perfect grab
# 12  p17_gold                                       perfect grab
# 13  p17_gold  and then you’re going to take one of them and ...
#
#                                            speech_amr  \
# 10                                         (o / okay)
# 10                                               None
# 10                                         (o / okay)
# 11  (b / block   :quant 1   :location (o / on-top-...
# 11                                               None
# 11  (b / block   :quant 1   :location (o / on-top-...
# 12                                      (p / perfect)
# 12                                               None
# 12                                      (p / perfect)
# 13  (a / and   :op2 (a2 / and          :op1 (t / t...
#
#                                        gesture_labels  \
# 10                                               None
# 10           [RA: move, front; RH: into point, down;]
# 10           [RA: move, front; RH: into point, down;]
# 11                                               None
# 11  [arms: rotate; hands: into point, down;, arms:...
# 11  [arms: rotate; hands: into point, down;, arms:...
# 12                                               None
# 12                                          [Unknown]
# 12                                          [Unknown]
# 13                                               None
#
#                                          gesture_amrs  num_gesture_amrs  \
# 10                                               None                 1
# 10  [(g / gesture-unit   :op1 (d / deixis-GA      ...                 1
# 10  [(g / gesture-unit   :op1 (d / deixis-GA      ...                 1
# 11                                               None                 1
# 11  [(g / gesture-unit   :op1 (d / deixis-GA      ...                 1
# 11  [(g / gesture-unit   :op1 (d / deixis-GA      ...                 1
# 12                                               None                 1
# 12  [(e / emblem-GA   :ARG0 (s / signaler)   :ARG1...                 1
# 12  [(e / emblem-GA   :ARG0 (s / signaler)   :ARG1...                 1
# 13                                               None                 2
#
#        prompt_type  group_id
# 10          speech         9
# 10         gesture         9
# 10  speech_gesture         9
# 11          speech        10
# 11         gesture        10
# 11  speech_gesture        10
# 12          speech        16
# 12         gesture        16
# 12  speech_gesture        16
# 13          speech        12

# %%
## Store the dataframes
test_dataframe = "test_df.pkl"
example_dataframe = "example_df.pkl"
pickle.dump(df_test, open(test_dataframe, 'wb'))
pickle.dump(df_example_set, open(example_dataframe, 'wb'))

# %%
# Point to the server
client = OpenAI(base_url="http://localhost:8000/v1", api_key="cltl")

# %%
# def write_prompt(prompt_type, speech_amr=None, gesture_amrs=None, gesture_labels=None, examples=None):
#     """
#     Generate prompt based on task type
#     """
#     if prompt_type == "speech":
#         prompt = "Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation."
#         if examples:
#             prompt += " First, read the examples to understand the Abstract Meaning Representation format:\n"
#             for i, ex in enumerate(examples):
#                 prompt += f"\nExample {i+1}:\n"
#                 prompt += f"Sentence: {ex['sentence']}\n"
#                 prompt += f"Speech AMR:\n {ulla.pretty_amr(ex['speech_amr'])}\n"
                
#             prompt += "\nNow, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:\n"
#             prompt += '[{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]\n'
#             prompt += f"Speech AMR:\n {ulla.pretty_amr(speech_amr)}\n"
#             #prompt += f"Sentence:\nExplanation:\n"
#             return prompt
            
#     elif prompt_type == "gesture":
#         prompt = "Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation."
#         if examples:
#             prompt += " First, read the examples to understand the Abstract Meaning Representation format:\n"
#             for i, ex in enumerate(examples):
#                 prompt += f"\nExample {i+1}:\n"
#                 prompt += f"Sentence: {ex['sentence']}\n"
#                 prompt += f"Speech AMR:\n {ulla.pretty_amr(ex['speech_amr'])}\n"
#                 prompt += f"\nGesture label(s): \n" + "\n".join(ex['gesture_labels']) + "\n"
#                 prompt += f"\nGesture AMR:\n"   #{ulla.pretty_amr(ex['gesture_amrs'])}\n
#                 for amr in ex["gesture_amrs"]:
#                     prompt += ulla.pretty_amr(amr) + "\n"
                    
#             prompt += "\nNow, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:\n"
#             prompt += '[{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]\n'
#             prompt += f"Gesture label(s):\n" + "\n".join(gesture_labels) + "\n"
#             prompt += f"Gesture AMR:\n"      #{ulla.pretty_amr(gesture_amrs)}\n"
#             for amr in gesture_amrs:
#                     prompt += ulla.pretty_amr(amr) + "\n"
#             #prompt += f"Sentence:\nSpeech AMR:\nExplanation:\n"
#             return prompt

#     elif prompt_type == "speech_gesture":
#         prompt = "Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation."
#         if examples:
#             prompt += " First, read the examples to understand the Abstract Meaning Representation format:\n"
#             for i, ex in enumerate(examples):
#                 prompt += f"\nExample {i+1}:\n"
#                 prompt += f"Sentence: {ex['sentence']}\n"
#                 prompt += f"Speech AMR:\n {ulla.pretty_amr(ex['speech_amr'])}\n"
#                 prompt += f"\nGesture label(s): \n" + "\n".join(ex['gesture_labels']) + "\n"
#                 prompt += f"\nGesture AMR:\n"  #{ulla.pretty_amr(ex['gesture_amrs'])}\n
#                 for amr in ex["gesture_amrs"]:
#                     prompt += ulla.pretty_amr(amr) + "\n" 
                    
#             prompt += "\nNow, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:\n"
#             prompt += '[{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]\n'
#             prompt += f"Gesture label(s):\n" + "\n".join(gesture_labels) + "\n"
#             prompt += f"Gesture AMR:\n"      #{ulla.pretty_amr(gesture_amrs)}\n"
#             for amr in gesture_amrs:
#                     prompt += ulla.pretty_amr(amr) + "\n"
#             prompt += f"Speech AMR:\n {ulla.pretty_amr(speech_amr)}\n"
#             #prompt += f"Sentence:\nExplanation:\n"
#             return prompt
    
#     else:
#         raise ValueError(f"Invalid prompt_type: {prompt_type}")

# def generate_prompt(df_test, examples):
#     """
    
#     """
#     prompts = []
#     #random.seed(seed_value)  # Set the seed to make it reproducible
    
#     example_idx = 0

#     for idx, row in df_test.iterrows():
#         #sampled_examples = random.sample(examples, 2)
#         sampled_examples = [examples[example_idx], examples[(example_idx + 1) % len(examples)]] 
#         example_idx = (example_idx + 2) % len(examples)
        
#         prompt = write_prompt(
#             prompt_type=row["prompt_type"],
#             speech_amr=row.get("speech_amr"),
#             gesture_amrs=row.get("gesture_amrs"),
#             gesture_labels=row.get("gesture_labels"),
#             examples=sampled_examples  
#         )
    
#         prompts.append({
#             "prompt": prompt,
#             "meta": {
#                 "sentence": row["sentence"],
#                 "scenario": row["prompt_type"],
#                 "file": row["file"]
#             }
#         })
#     return prompts

# def query_LLM(model_client, prompt, temp=0.3):
#     history = [
#         {"role": "system", "content": prompt},
#     ]
#     completion = model_client.chat.completions.create(
#         model="local-model", # this field is currently unused
#         messages=history,
#         temperature=temp,
#         #max_tokens=2048,
#         top_p=0.9,
#         stream=False,
#         seed=2201
#     )
#     return completion.choices[0].message.content

# def query_LLM_multiple(model_client, prompt, temp=0.3, n=3):
#     completions = []
#     for i in range(n):
#         response = model_client.chat.completions.create(
#             model="local-model",  
#             messages=[{"role": "system", "content": prompt}],
#             temperature=temp,
#             max_tokens=2048,
#             stream=False,
#             seed=13 + i                    ## Slightly vary seed for different outputs
#         )
#         completions.append(response.choices[0].message.content)
#     return completions

# %%
## Turn example df into a list of dicts
examples = []

for idx, row in df_example_set.iterrows():
    examples.append({
        "sentence": row.get("sentence"),
        "speech_amr": row.get("speech_amr"),
        "gesture_amrs": row.get("gesture_amrs"),
        "gesture_labels": row.get("gesture_labels"),
        "num_gesture_amrs": row.get("num_gesture_amrs"),
    })

## These are all the example sentences that will be given to Llama.
for item in examples:
    print(item['sentence'])
# Out:
# okay
# space two out a little less than a block length
# and you can you can place them close to each other
# it cannot fall down from the ground right
# on the side with three the one closest to the middle put another block on top
# now these are a little jiggled
# you're done
# put a bit a bit right uh
# it starts in the top left
# yea yea and then it
# it's gonna be a pyramid from three of the rows of two
# the three blocks all touch and they’re straight
# okay
# stack stack it up no
# move that block uh
# they’re in other words are not perfectly clear
# them towards you
# gonna have another block right next to that block so it’d be over the space of those two bottom blocks
# just one
# and go
# the base is going to have four second one’s going to have three then two on top of that and then one
# start off with just a block and then put a block on top of
# okay and
# stack three blocks on one side yup
# like about a third of a block a part so more close in than that
# and then the second block goes on top of that
# great yep
# seven blocks in a row
# touching corners touching corners
# the first block is like is like like the first tower yeah
# starting at row three column three
# yeah great
# that one okay
# block the goes on top of the block you just placed but not totally centered
# and one block on the right side of the first block and move back a bit
# take one block put it on top of those two in the middle
# the block you have in your left hand or in your hands goes in between that diagonal shape yep
# and uh two blocks
# more great
# spread them apart a little bit but not as wide as a full block
# all right put a block down
# ever so slightly alright
# then you going to have a fourth block
# and then take the two on top
# two eyes first
# like not stacked
# then the gap should be a little less of between him
# almost like that
# stick it on the other side divot
# it kind of goes down diagonally or so in yours
# four blocks
# that looks good
# ah now uh move it so it's on the front front one and the one you just put it on
# the blocks are turned like half way on top of each block yeah
# yep and then get the last block or another block and put it on top of the one
# the right were were about correct
# four blocks in the front okay
# on that exactly on that axis so
# and then three more coming off from the other direction touching the corner okay
# move that about one that tower about one block over
# place it such that they are like interleaving
# think of like a wifi signal where it’s a u shape
# just like that and then you’re gonna do that one more time in the same direction so it’s kind of like a slanting height three yeah
# not not too much
# okay perfect
# i want you take one block
# scoot it over so there's the blocks are flush on one side
# so like fanned out away from you
# just turn it turn it vertical okay
# yeah
# in the middle
# and turn it so it's parallel
# yup
# then that’s it for your base uh your height you’re every
# and then there must be one a hard that i'm having time seeing behind
# place it so it's um sitting in between the two like that
# okay
# put a block on like like on the crack of those two blocks
# three to one but they all gonna be rotated a
# put a block one block apart behind
# right there uh
# between the block you just placed and the third block on that side it's touching those two corners
# alright
# it's just on the table
# move forward a bit
# both sides
# alright grab three blocks
# then a last block on the crack of those two blocks
# take one block and put it on the table
# alright move one of the blocks off to the side
# yea on the side with four on the last one on the inside corner there is another block yeah
# closest to the middle yeah
# one block on each side
# five blocks in a row right in front of them
# five blocks to start
# but it's still in berlin
# please close a little bit the base the base
# so that’s our new you did not miss from in right blocks space
# move them this direction like you had it before so they’re touching corners
# on top of that you're going to between the overlapping the two you're going to have two blocks or the uh middle three
# so you could squeeze them together a little bit there you go
# have two blocks right next to each other
# like they're all stacked right on top of each other
# stick them on the table in a line in front of you
# put them to the side of that little section so they line up
# they gonna be all connecting
# yea and touching corners
# i want you to tilt all of them so that the one corner is touching
# three blocks
# it will be diagonal like a diamond no no no
# make a little bit of gap but in line with the back block okay
# and then grab another block
# so starting from the top moving to your left down four diagonally a row with the corners
# get another one stacked on top
# yep
# it stacks like straight up
# maybe just pushed like slightly in the same
# the third block is it's on top of that block but it's pushed just slightly to the a off of it
# one on the your le- yeah that one your left side its gonna be just one on top
# keep them like turn them hor- vertically
# good
# and they are just straight
# um i think everything needs to be slightly closer together
# you see how there are three divots
# get two blocks and put them on the
# no no
# close a little bit more not
# but bothe opposite way like
# yeah
# now stick a block on the front one and the one to your left
# every things on top of that
# and then put the third one on the fourth one on top of these the middle one
# we’ll have another block just falling down as if it just for fell down from heaven
# then they connect to the two wider blocks
# and two blocks like making it smile
# the bottom layer starts with four blocks
# all right then stick
# and do the exact same thing there
# behind the two one and
# that's it
# and there's one touching that block's bottom corner
# okay and they’e just kind of jiggled around
# and one block left of the first block first block and a bit in front of it
# this one looks like a (oh sorry) this one looks like a smiley face
# save on the fourth block on the other side
# one block on top of the both
# now the ones i just told you to put that were two that last two i told you to put
# yeah and
# get two more blocks
# one right next to it touching
# get two blocks
# looks like like a like jenga
# and a little near you
# center them on top of where the three blocks meet on it either side
# they're more laid out in a flower pattern
# scoot the five over
# and don't rotate don't don't rotate yeah
# this one is like three towers next to each other
# yeah
# grab one more block place
# and then there's two blocks um a little bit like out and then down or up for you
# and it's turned at an angle
# yes
# now do it on the other side
# close even more close but not touching yeah
# those too blocks right next each other
# you have two blocks on top of these
# just like you’re building a tower
# we’re building up a even column i guess so
# i'm not sure yeah
# okay this one's somewhat similar to the last one except it's a four four layers
# don’t do that exactly
# pushed off like the same direction
# and um the middle tower
# count in with your left hand count to block three and four
# and one block pick up one block and it is in front of the block you just put it and rotate it forty five degrees
# so then your next one is going to be up one and it's going to be shifted over half a block to
# good enough good enough
# towards to me at the top layer block
# just four

# %%
## Generate all prompts that will be given to Llama to check that the inputs etc are correct
prompts = ulla.generate_prompt(df_test, examples)
for item in prompts:
    print(item['prompt'])
# Out:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay
# Speech AMR:
#  (o/okay-04)
#
# Example 2:
# Sentence: space two out a little less than a block length
# Speech AMR:
#  (s/space-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/implicit-role
# 		:quant 2)
# 	:ARG2 (q/distance-quantity
# 		:unit (b/block)
# 		:ARG1-of (h/have-quant-91
# 			:ARG2 1
# 			:ARG3 (l/less
# 				:mod (l2/little)))))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1)
# 	:ARG2 (b2/block
# 		:mod (b3/back)))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and you can you can place them close to each other
# Speech AMR:
#  (a/and
# 	:op2 (p/possible-01
# 		:ARG1 (p2/place-01
# 			:ARG0 (y/you)
# 			:ARG1 (t/them)
# 			:purpose (c/close-10
# 				:ARG1 t
# 				:ARG2 (o/other
# 					:mod (e/each))))))
#
# Gesture label(s):
# hands: into open, back;
# hands: beckon, back;
# LH: into closed, right; RH: into closed, up;
# arms: apart, left; RH: into closed, left;
# hands: shake, left;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: it cannot fall down from the ground right
# Speech AMR:
#  (p/possible-01
# 	:polarity -
# 	:ARG1 (f/fall-01
# 		:ARG1 (i/it)
# 		:ARG3 (g/ground))
# 	:ARG1-of (r/request-confirmation-91))
#
# Gesture label(s):
# head: shake; hands: rotate, open, up;
# Unknown
# LA: move, down; LH: into point, front;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: point, front;
# RA: move, down; RH: into claw, down;
# RA: move, up; RH: into point, front;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: on the side with three the one closest to the middle put another block on top
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another))
# 	:ARG2 (o/on-top
# 		:op1 (o2/one
# 			:ARG1-of (h/have-degree-91
# 				:ARG2 (c/close-10
# 					:ARG1 o2
# 					:ARG2 (m/middle))
# 				:ARG3 (m2/most))
# 			:location (o3/on
# 				:op1 (s/side
# 					:ARG0-of (h2/have
# 						:ARG1 (i2/implicit-role
# 							:quant 3)))))))
#
# Gesture label(s):
# body: still;
# LA: move, left; LH: into open, front;
# body: still;
# LH: into point, front;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/side)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: now these are a little jiggled
# Speech AMR:
#  (j/jiggle-01
# 	:ARG1 (t/these)
# 	:mod (l/little))
#
# Gesture label(s):
# head: nod; LA: move, back;
# RA: move, up; RH: shake, down, open;
# RA: move, front; RH: into point, down;
#
# Gesture AMR:
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (j/jiggle-01)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: point, front;
# RA: move, down; RH: into claw, down;
# RA: move, up; RH: into point, front;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1)
# 	:ARG2 (b2/block
# 		:mod (b3/back)))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: you're done
# Speech AMR:
#  (d/done-08
# 	:ARG0 (y/you))
#
# Example 2:
# Sentence: put a bit a bit right uh
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG2 (r/right-04
# 		:degree (b/bit)))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 2))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: it starts in the top left
# Speech AMR:
#  (s/start-01
# 	:ARG0 (i/it)
# 	:location (i2/in
# 		:op1 (l/left
# 			:mod (t/top))))
#
# Gesture label(s):
# Unknown
# LH: into claw, down;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: yea yea and then it
# Speech AMR:
#  (g/good
# 	:domain (t/that))
#
# Gesture label(s):
# head: move, up, nod; LA: move, up; LH: into thumbs, up;
# body: move, down; head: move, down; LA: move, down; LH: into open, down;
# body: still;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, gap, left; hands: claw, down;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: it's gonna be a pyramid from three of the rows of two
# Speech AMR:
#  (p/pyramid
# 	:consist-of (r/row
# 		:quant 3
# 		:consist-of (r2/row
# 			:quant 2))
# 	:domain (i/it))
#
# Gesture label(s):
# body: move, front; LA: move, down;
# body: move, front; arms: into gap, left; hands: facing, into open;
# arms: move, down;
# RA: move, left;
# RA: shake, right;
# RA: move, down;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (d/deixis-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (l/location)
# 			:ARG2 (a2/actor))
# 		:op2 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (p/put-01)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)
# 		:op2 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01)
# 			:ARG2 a2)))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Example 2:
# Sentence: the three blocks all touch and they’re straight
# Speech AMR:
#  (a/and
# 	:op1 (t/touch-01
# 		:ARG0 (b/block
# 			:quant 3))
# 	:op2 (s/straight-04
# 		:ARG1 (t2/they)))
#
# Gesture label(s):
# Unknown
# hands: into claw, front;
# arms: move, back; hands: closed, back;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/together)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/straight)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, gap, left; hands: claw, down;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 2))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay
# Speech AMR:
#  (o/okay-04)
#
# Example 2:
# Sentence: stack stack it up no
# Speech AMR:
#  (s/stack-up-03
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/it))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (u/um
# 	:mode expressive)
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: move that block uh
# Speech AMR:
#  (m/move-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (t/that)))
#
# Gesture label(s):
# LA: move, right; LH: claw, right;
# LH: rotate, claw, front;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: they’re in other words are not perfectly clear
# Speech AMR:
#  (c/clear-06
# 	:manner (w/words
# 		:mod (o/other))
# 	:ARG1 (t/they)
# 	:polarity -
# 	:ARG1-of (p/perfect-02))
#
# Gesture label(s):
# Unknown
# body: still;
# hands: enough;
#
# Gesture AMR:
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (k/know-01
# 		:polarity -)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (e2/enough)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: rotate, gap, left; hands: claw, down;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: them towards you
# Speech AMR:
#  (o/orient-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/them
# 		:location (t2/towards
# 			:op1 y)))
#
# Gesture label(s):
# hands: claw, down; LA: move, back; RA: move, front;
# hands: claw, down; LA: move, front; RA: move, back;
# hands: claw, down; LA: move, back; RA: move, front;
# hands: into closed, back; RA: move, back;
# arms: move, front, into gap, left; hands: facing, into closed;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (b/block)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01)
# 		:ARG2 a))
#
# Example 2:
# Sentence: gonna have another block right next to that block so it’d be over the space of those two bottom blocks
# Speech AMR:
#  (h/have-02
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another))
# 	:location (n/next-to
# 		:ARG1 (t/that)
# 		:mod (r/right))
# 	:purpose (b2/be-located-at-91
# 		:ARG1 b
# 		:ARG2 (o/over
# 			:op1 (s/space
# 				:poss (b3/block
# 					:mod (t/that)
# 					:location (b4/bottom))))))
#
# Gesture label(s):
# RA: move, up; RH: into open, left;
# RA: move, right;
# LA: move, front; RA: move, down; hands: into open, back;
# head: move, right;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/space)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: rotate, gap, left; hands: claw, down;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
# Speech AMR:
#  (u/um
# 	:mode expressive)
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: just one
# Speech AMR:
#  (i/implicit-role
# 	:quant 1)
#
# Example 2:
# Sentence: and go
# Speech AMR:
#  (a/and)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (a/and
# 	:op2 (p/put-01
# 		:mode imperative
# 		:time (t/then)
# 		:ARG0 (y/you)
# 		:ARG1 (o/one)
# 		:ARG2 (o2/on
# 			:op1 (t2/top))))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the base is going to have four second one’s going to have three then two on top of that and then one
# Speech AMR:
#  (a/and
# 	:op1 (h/have-03
# 		:ARG0 (b/base)
# 		:ARG1 (i/implicit-role
# 			:quant 4))
# 	:op2 (h2/have-03
# 		:ARG0 (i2/implicit-role
# 			:ord (o/ordinal-entity
# 				:value 2))
# 		:ARG1 (i3/implicit-role
# 			:quant 3))
# 	:op3 (i4/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i5/implicit-role
# 			:quant 2)
# 		:destination (o2/on-top-of
# 			:op1 (t/that)))
# 	:op4 (i6/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (i7/implicit-role
# 			:quant 1)))
#
# Gesture label(s):
# RA: move, up; RH: into four, front;
# RH: into three;
# RA: move, up; RH: into two;
# RH: into one;
# RA: move, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 4
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 3
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 2
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: start off with just a block and then put a block on top of
# Speech AMR:
#  (a/and
# 	:op1 (s/start-off-2
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:mod (j/just)))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (b2/block)
# 		:ARG2 (o/on
# 			:op1 (t/top
# 				:op1 (t2/that)))
# 		:time (t3/then)))
#
# Gesture label(s):
#     arms: move, up, into gap, left; hands: into facing, left, into claw, left;
#     head: move, down;
# head: move, up; arms: move, down; hands: into open, down;
# body: move, up; RH: tap;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/top)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, up; RH: into point, front;
# Unknown
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay and
# Speech AMR:
#  (o/okay)
#
# Gesture label(s):
# body: still;
# RA: move, right; RH: into closed, front;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/side)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: stack three blocks on one side yup
# Speech AMR:
#  (s/stack-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 3)
# 	:ARG2 (o/on
# 		:op1 (s2/side
# 			:quant 1)))
#
# Gesture label(s):
# Unknown
# RA: move, right; RH: into point, down;
# RH: tap, point;
# RA: move, up; RH: into claw, front;
# RA: move, down;
# LA: move, to hip;
# body: still;
# head: nod;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/stack-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, up; RH: into point, front;
# Unknown
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (a/and
# 	:op2 (p/put-01
# 		:mode imperative
# 		:time (t/then)
# 		:ARG0 (y/you)
# 		:ARG1 (o/one)
# 		:ARG2 (o2/on
# 			:op1 (t2/top))))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: like about a third of a block a part so more close in than that
# Speech AMR:
#  (l/like-04
# 	:ARG2 (q/distance-quantity
# 		:mod (a/about)
# 		:unit (b/block
# 			:ARG1-of (h/have-quant-91
# 				:ARG2 (t/third)))
# 		:mod (a2/apart))
# 	:ARG2-of (i/infer-01
# 		:ARG1 (h2/have-degree-91
# 			:ARG2 (c/close-10)
# 			:ARG3 (m/more)
# 			:ARG4 (t2/that))))
#
# Example 2:
# Sentence: and then the second block goes on top of that
# Speech AMR:
#  (g/go-01
# 	:ARG1 (b/block
# 		:ord (o/ordinal-entity
# 			:value 2);ARG4(o2/on
# 			:op1 (t/top
# 				:location (t2/that)))))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (l/look-02
# 		:ARG0 (t/that)
# 		:ARG1 (w/work-09)
# 		:polarity -))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: great yep
# Speech AMR:
#  (g/great)
#
# Gesture label(s):
# hands: thumb, up;
# head: nod;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/good)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: seven blocks in a row
# Speech AMR:
#  (i/implicit-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 7)
# 	:manner (r/row))
#
# Gesture label(s):
# Unknown
# arms: move, up; LH: into two, front; RH: into five, front;
# LA: move, down; RA: move, right; RH: closed, down;
# RA: move, back;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 7
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/place-01)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down; hands: into claw, down;
# body: still;
# arms: move, up; hands: into claw, down;
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/grab-01
# 		:ARG1 (b/block
# 			:quant 2))
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-06)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: touching corners touching corners
# Speech AMR:
#  (t/touch-01
# 	:ARG0 (c/corner)
# 	:ARG1 (c2/corner))
#
# Gesture label(s):
# RA: move, up; hands: into contact, left;
# body: still;
# head: nod;
# body: still;
# head: nod;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/touch-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: the first block is like is like like the first tower yeah
# Speech AMR:
#  (s/similar-01
# 	:ARG0 (b/block
# 		:ord (o/ordinal-entity
# 			:value 1))
# 	:ARG1 (t/tower
# 		:ord (o2/ordinal-entity
# 			:value 1)))
#
# Gesture label(s):
# body: move, down; hands: into open, down;
# hands: into facing, left, into open, left;
# arms: shake, up;
# RA: shake, up left;
# body: still;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower
# 				:ord (o/ordinal-entity
# 					:value 1))
# 			:ARG2 a2)
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 t
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down; hands: into claw, down;
# body: still;
# arms: move, up; hands: into claw, down;
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/grab-01
# 		:ARG1 (b/block
# 			:quant 2))
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-06)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (l/look-02
# 		:ARG0 (t/that)
# 		:ARG1 (w/work-09)
# 		:polarity -))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: starting at row three column three
# Speech AMR:
#  (s/start-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/be-located-at-91
# 		:ARG1 (a/and
# 			:op1 (r/row
# 				:ord (t/third))
# 			:op2 (c/column
# 				:ord 3))))
#
# Example 2:
# Sentence: yeah great
# Speech AMR:
#  (y/yeah)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (y/yes)
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: that one okay
# Speech AMR:
#  (o/one
# 	:mod (t/that))
#
# Gesture label(s):
# head: nod;
# body: move, left;
# body: still;
# RA: move, right; RH: into closed, front;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/side)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: block the goes on top of the block you just placed but not totally centered
# Speech AMR:
#  (i/implicit-predicate-00
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another)
# 		:ARG1-of (b2/be-located-at-91
# 			:ARG2 (c/contrast-01
# 				:ARG1 (o/on
# 					:op1 (t/top
# 						:poss b
# 						:ARG1-of (p/place-01
# 							:ARG0 b
# 							:time (j/just))))
# 				:ARG2 (c2/center-01
# 					:polarity -
# 					:mod (t2/total))))))
#
# Gesture label(s):
# body: still;
# LA: move, up; LH: into point, front;
# body: still;
# body: move, down; arms: move, down; hands: into open, back down;
# body: still;
# head: rotate;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# body: still;
# RA: move, up; RH: claw, down;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and one block on the right side of the first block and move back a bit
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 1
# 		:location (o/on
# 			:op1 (s/side
# 				:ARG1-of (r/right-04)
# 				:poss (b2/block
# 					:ord (o2/ordinal-entity
# 						:value 1)))))
# 	:op3 (m/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:direction (b3/back
# 			:degree (b4/bit))))
#
# Gesture label(s):
# Unknown
# Rh: into fist, back;
# body: still;
# Unknown
# hands: into facing, left;
# arms: beckon;
# body: still;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (b/backward))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: take one block put it on top of those two in the middle
# Speech AMR:
#  (a/and
# 	:op1 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:quant 1))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 b
# 		:ARG2 (o/on-top-of
# 			:op1 (b2/block
# 				:mod (t2/that)
# 				:quant 2
# 				:location (m/middle)))))
#
# Gesture label(s):
# RA: move, up; RH: into one, front;
# RA: move, front; RH: into L, down;
# RA: move, up; RH: L, down;
# RA: move, back;
# body: still;
# RA: move, down; RH: into point, down;
# LA: move, left; LH: into L, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# body: still;
# RA: move, up; RH: claw, down;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (y/yes)
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the block you have in your left hand or in your hands goes in between that diagonal shape yep
# Speech AMR:
#  (g/go-35
# 	:ARG1 (b/block
# 		:ARG1-of (h/have-03
# 			:ARG0 (y/you)
# 			:location (i/in
# 				:op1 (h2/hand
# 					:poss y))))
# 	:ARG2 (i2/in
# 		:op1 (b2/between
# 			:op1 (s/shape
# 				:mod (t/that)
# 				:mod (d/diagonal)))))
#
# Example 2:
# Sentence: and uh two blocks
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 2))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (j/jiggle-01
# 	:mode imperative
# 	:ARG0 (y/you))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: more great
# Speech AMR:
#  (m/more)
#
# Gesture label(s):
# hands: shake, left;
# Unknown
# hands: into fist, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: spread them apart a little bit but not as wide as a full block
# Speech AMR:
#  (s/spread-03
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/them)
# 	:direction (a/apart
# 		:quant (b/bit
# 			:mod (l/little))
# 		:quant (l2/less-than
# 			:op1 (q/distance-quantity
# 				:unit (b2/block)
# 				:quant 1))))
#
# Gesture label(s):
# arms: move, into gap, left; hands: facing, closed;
# body: still;
# arms: move, back;
# RA: move, up; RH: into one, front;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/spread-03
# 		:direction (a/apart))
# 	:ARG2 (a2/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: into point, down;
# RH: shake, down;
# RH: into point, front;
# Unknown
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (c/count-01
# 			:ARG2 (a/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: all right put a block down
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1
# 		:direction (d/down))
# 	:mod (a/all-right))
#
# Gesture label(s):
# RA: move, front left; RH: into claw, down;
# body: still;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (p/put-01)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Example 2:
# Sentence: ever so slightly alright
# Speech AMR:
#  (s/slight
# 	:degree (s2/so
# 		:mod (e/ever)))
#
# Gesture label(s):
# body: still;
# hands: into open, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: into point, down;
# RH: shake, down;
# RH: into point, front;
# Unknown
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (c/count-01
# 			:ARG2 (a/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
# Speech AMR:
#  (j/jiggle-01
# 	:mode imperative
# 	:ARG0 (y/you))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: then you going to have a fourth block
# Speech AMR:
#  (h/have-03
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:ord 4))
#
# Example 2:
# Sentence: and then take the two on top
# Speech AMR:
#  (a/and
# 	:op2 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/implicit-role
# 			:quant 2
# 			:location (o/on
# 				:op1 (t2/top))))
# 	:mod (t3/then))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (e/enough-01
# 	:ARG2 (g/good))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: two eyes first
# Speech AMR:
#  (e/eye
# 	:quant 2
# 	:li 1)
#
# Gesture label(s):
# arms: into gap, left; hands: into claw, down;
# arms: apart, left;
# Unknown
# body: still;
#
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (p/put-01)
# 		:ARG2 (a2/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p2/put-01)
# 		:ARG2 a2))
#
# Example 2:
# Sentence: like not stacked
# Speech AMR:
#  (s/stack-01
# 	:polarity -)
#
# Gesture label(s):
# body: still;
# RA: move, up, surround; RH: into point, down;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, up; hands: into open, front;
# body: move, back; arms: move, down;
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: then the gap should be a little less of between him
# Speech AMR:
#  (b/be-03
# 	:ARG0 (g/gap)
# 	:degree (l/less
# 		:mod (l2/little))
# 	:mod (b2/between
# 		:ARG1 (t/them)))
#
# Gesture label(s):
# arms: move, up; hands: facing, into gap, left;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/less)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/squeeze
# 		:direction (t/together))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: almost like that
# Speech AMR:
#  (l/like-04
# 	:ARG1 (t/that)
# 	:mod (a/almost))
#
# Gesture label(s):
# Unknown
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (r/rotate-01)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, up; hands: into open, front;
# body: move, back; arms: move, down;
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (e/enough-01
# 	:ARG2 (g/good))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: stick it on the other side divot
# Speech AMR:
#  (s/stick-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/it)
# 	:ARG2 (d/divot
# 		:poss (s2/side
# 			:mod (o/other))))
#
# Example 2:
# Sentence: it kind of goes down diagonally or so in yours
# Speech AMR:
#  (g/go-06
# 	:ARG0 (i/it)
# 	:ARG2 (d/down)
# 	:manner (a/about
# 		:op1 (d2/diagonal))
# 	:location (i2/in
# 		:op1 (i3/implicit-role
# 			:poss (y/you)))
# 	:degree (k/kind-of))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (a/and
# 	:op1 (j/jiggle-01
# 		:time (t/then)
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/implicit-role
# 			:quant 2
# 			:location (f/front
# 				:poss (t2/them)))))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: four blocks
# Speech AMR:
#  (b/block
# 	:quantity 4)
#
# Gesture label(s):
# Unknown
# RA: move, up; RH: into four, left;
# hands: into hold;
# body: still;
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 4
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: that looks good
# Speech AMR:
#  (l/look-02
# 	:ARG0 (t/that)
# 	:ARG1 (g/good))
#
# Gesture label(s):
# Unknown
# arms: move, up; hands: into thumbs, up;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# hands: shake, closed;
# hands: shake, front, into point, down;
# arms: move, down;
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (j/jiggle-01)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/slide-01
# 			:direction (f/forward))
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: ah now uh move it so it's on the front front one and the one you just put it on
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (m2/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/it)
# 		:purpose (b/be-located-at-91
# 			:ARG1 i
# 			:ARG2 (a/and
# 				:op1 (o/one
# 					:mod (f/front))
# 				:op2 (o2/one
# 					:ARG2-of (p/put-01
# 						:ARG0 y
# 						:time (j/just)))))))
#
# Gesture label(s):
# RA: move, up right; RH: into closed, left;
# RA: move, left; RH: closed, left;
# RA: move, front; RH: into point, front;
# RA: move, down back; RH: point, down;
# RA: move, front right; RH: point, down;
# body: still;
# RA: move, up; RH: into claw, front;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (m/move-01
# 			:direction (f/front))
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/turn
# 		:ARG1 (b/block))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: the blocks are turned like half way on top of each block yeah
# Speech AMR:
#  (t/turn-01
# 	:ARG1 (b/block)
# 	:ARG2 (h/halfway)
# 	:location (o/on
# 		:op1 (t2/top
# 			:mod b
# 			:quant (e/each))))
#
# Gesture label(s):
# arms: rotate; hands: into opposed, left, into open, left;
# hands: rotate;
# RH: rotate;
# LA: move, down; LH: into open, up; RH: rotate;
# hands: rotate;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/turn-01)
# 	:ARG2 (a/actor))
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (d/deixis-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (l/location)
# 			:ARG2 (a2/actor))
# 		:op2 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a2)
# 		:op2 (i3/icon-GA
# 			:ARG0 s
# 			:ARG1 (t2/turn-01)
# 			:ARG2 a2)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# hands: shake, closed;
# hands: shake, front, into point, down;
# arms: move, down;
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (j/jiggle-01)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/slide-01
# 			:direction (f/forward))
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
# Speech AMR:
#  (a/and
# 	:op1 (j/jiggle-01
# 		:time (t/then)
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/implicit-role
# 			:quant 2
# 			:location (f/front
# 				:poss (t2/them)))))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: yep and then get the last block or another block and put it on top of the one
# Speech AMR:
#  (a/and
# 	:op1 (g/get-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (o/or
# 			:op1 (b/block
# 				:mod (l/last)
# 				:op2 (b2/block
# 					:mod (a/another))))
# 		:op2 (p/put-01
# 			:mode imperative
# 			:ARG0 y
# 			:ARG1 (i/it)
# 			:ARG2 (o2/on
# 				:op1 (t/top
# 					:poss (o3/one))))))
#
# Example 2:
# Sentence: the right were were about correct
# Speech AMR:
#  (c/correct-01
# 	:ARG0 (t/those
# 		:quant 2
# 		:location (r/right)))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (a/and
# 	:op1 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:mod (a2/another)))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 b
# 		:ARG2 (n/next-to
# 			:op1 (i/it))))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: four blocks in the front okay
# Speech AMR:
#  (b/block
# 	:quant 4
# 	:location (i/in
# 		:op1 (f/front)))
#
# Gesture label(s):
# arms: shake, left; hands: into claw, down;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (r/row)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: on that exactly on that axis so
# Speech AMR:
#  (o/on
# 	:op1 (a/axis
# 		:mod (t/that)))
#
# Gesture label(s):
# body: still;
# Unknown
#
# Gesture AMR:
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: into point, down;
# body: still;
# RA: move, back;
# arms: move, into gap, left; hands: facing, closed;
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/spread-03
# 		:direction (a/apart))
# 	:ARG2 (a2/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and then three more coming off from the other direction touching the corner okay
# Speech AMR:
#  (a/and
# 	:op2 (i/implicit-role
# 		:quant 3
# 		:mod (m/more)
# 		:ARG1-of (c/come-33
# 			:ARG3 (f/from
# 				:op1 (d/direction
# 					:mod (o/other)))
# 			:mod (o2/off))
# 		:ARG0-of (t/touch-01
# 			:ARG1 (c2/corner))
# 		:time (t2/then)))
#
# Gesture label(s):
# body: still;
# LA: move, left; LH: into closed, front;
# body: still;
# head: nod; LA: move, right; LH: into closed, right;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (d/direction)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: move that about one that tower about one block over
# Speech AMR:
#  (m/move-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/tower
# 		:mod (t2/that))
# 	:ARG2 (a/about
# 		:op1 (q/distance-quantity
# 			:unit (b/block)
# 			:quant 1))
# 	:direction (o/over))
#
# Gesture label(s):
# LA: move, front; LH: into claw, front;
# LA: shake, up; LH: claw, front;
# LA: move, left; LH: front, claw;
# body: still;
# arms: move, up; hands: into open, up;
# body: move, back; arms: move, down;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/tower)
# ...
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/space)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# hands: rotate, into closed, up;
# body: move, down; arms: move, front; hands: into closed, back;
# arms: shake, front;
# body: move, up; arms: move, back; hands: into claw, down;
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (d/deixis-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (l/location)
# 			:ARG2 (a2/actor))
# 		:op2 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (f/far)
# 			:ARG2 a2)
# 		:op2 (g2/gesture-unit
# 			:op1 (d2/deixis-GA
# 				:ARG0 s
# 				:ARG1 l
# 				:ARG2 a2)
# 			:op2 (i2/icon-GA
# 				:ARG0 s
# 				:ARG1 f
# 				:ARG2 a2))))
# Speech AMR:
#  (i/implicit-predicate-00
# 	:ARG1 (d/divot
# 		:quant 3
# 		:ARG1-of (h/have-degree-91
# 			:ARG2 (f/far
# 				:op1 (y/you))
# 			:ARG3 (m/most))))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: just one
# Speech AMR:
#  (i/implicit-role
# 	:quant 1)
#
# Example 2:
# Sentence: and go
# Speech AMR:
#  (a/and)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (g/get-01
# 	:ARG0 (y/you)
# 	:ARG1 (t/tower
# 		:quantity 2
# 		:location (o/on
# 			:op1 (s/sides))))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the base is going to have four second one’s going to have three then two on top of that and then one
# Speech AMR:
#  (a/and
# 	:op1 (h/have-03
# 		:ARG0 (b/base)
# 		:ARG1 (i/implicit-role
# 			:quant 4))
# 	:op2 (h2/have-03
# 		:ARG0 (i2/implicit-role
# 			:ord (o/ordinal-entity
# 				:value 2))
# 		:ARG1 (i3/implicit-role
# 			:quant 3))
# 	:op3 (i4/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i5/implicit-role
# 			:quant 2)
# 		:destination (o2/on-top-of
# 			:op1 (t/that)))
# 	:op4 (i6/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (i7/implicit-role
# 			:quant 1)))
#
# Gesture label(s):
# RA: move, up; RH: into four, front;
# RH: into three;
# RA: move, up; RH: into two;
# RH: into one;
# RA: move, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 4
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 3
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 2
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: start off with just a block and then put a block on top of
# Speech AMR:
#  (a/and
# 	:op1 (s/start-off-2
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:mod (j/just)))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (b2/block)
# 		:ARG2 (o/on
# 			:op1 (t/top
# 				:op1 (t2/that)))
# 		:time (t3/then)))
#
# Gesture label(s):
#     arms: move, up, into gap, left; hands: into facing, left, into claw, left;
#     head: move, down;
# head: move, up; arms: move, down; hands: into open, down;
# body: move, up; RH: tap;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/top)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
# arms: shake, left;
# arms: rotate; hands: into opposed, left, into open, left;
# Gesture AMR:
# (d/deixis-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay and
# Speech AMR:
#  (o/okay)
#
# Gesture label(s):
# body: still;
# RA: move, right; RH: into closed, front;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/side)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: stack three blocks on one side yup
# Speech AMR:
#  (s/stack-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 3)
# 	:ARG2 (o/on
# 		:op1 (s2/side
# 			:quant 1)))
#
# Gesture label(s):
# Unknown
# RA: move, right; RH: into point, down;
# RH: tap, point;
# RA: move, up; RH: into claw, front;
# RA: move, down;
# LA: move, to hip;
# body: still;
# head: nod;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/stack-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
# arms: shake, left;
# arms: rotate; hands: into opposed, left, into open, left;
# Gesture AMR:
# (d/deixis-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (g/get-01
# 	:ARG0 (y/you)
# 	:ARG1 (t/tower
# 		:quantity 2
# 		:location (o/on
# 			:op1 (s/sides))))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: like about a third of a block a part so more close in than that
# Speech AMR:
#  (l/like-04
# 	:ARG2 (q/distance-quantity
# 		:mod (a/about)
# 		:unit (b/block
# 			:ARG1-of (h/have-quant-91
# 				:ARG2 (t/third)))
# 		:mod (a2/apart))
# 	:ARG2-of (i/infer-01
# 		:ARG1 (h2/have-degree-91
# 			:ARG2 (c/close-10)
# 			:ARG3 (m/more)
# 			:ARG4 (t2/that))))
#
# Example 2:
# Sentence: and then the second block goes on top of that
# Speech AMR:
#  (g/go-01
# 	:ARG1 (b/block
# 		:ord (o/ordinal-entity
# 			:value 2);ARG4(o2/on
# 			:op1 (t/top
# 				:location (t2/that)))))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (d/do-02
# 	:ARG0 (y/you)
# 	:ARG1 (p/process
# 		:mod (s/same))
# 	:mod (a/all)
# 	:manner (u/up)))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: great yep
# Speech AMR:
#  (g/great)
#
# Gesture label(s):
# hands: thumb, up;
# head: nod;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/good)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: seven blocks in a row
# Speech AMR:
#  (i/implicit-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 7)
# 	:manner (r/row))
#
# Gesture label(s):
# Unknown
# arms: move, up; LH: into two, front; RH: into five, front;
# LA: move, down; RA: move, right; RH: closed, down;
# RA: move, back;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 7
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/place-01)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into point, left;
# RA: rotate, into point, left;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01
# 			:mod (u/up))
# 		:ARG2 a2)
# 	:op1 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r2/rotate-01)
# 		:ARG2 a2))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: touching corners touching corners
# Speech AMR:
#  (t/touch-01
# 	:ARG0 (c/corner)
# 	:ARG1 (c2/corner))
#
# Gesture label(s):
# RA: move, up; hands: into contact, left;
# body: still;
# head: nod;
# body: still;
# head: nod;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/touch-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: the first block is like is like like the first tower yeah
# Speech AMR:
#  (s/similar-01
# 	:ARG0 (b/block
# 		:ord (o/ordinal-entity
# 			:value 1))
# 	:ARG1 (t/tower
# 		:ord (o2/ordinal-entity
# 			:value 1)))
#
# Gesture label(s):
# body: move, down; hands: into open, down;
# hands: into facing, left, into open, left;
# arms: shake, up;
# RA: shake, up left;
# body: still;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower
# 				:ord (o/ordinal-entity
# 					:value 1))
# 			:ARG2 a2)
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 t
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into point, left;
# RA: rotate, into point, left;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01
# 			:mod (u/up))
# 		:ARG2 a2)
# 	:op1 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r2/rotate-01)
# 		:ARG2 a2))
# Speech AMR:
#  (d/do-02
# 	:ARG0 (y/you)
# 	:ARG1 (p/process
# 		:mod (s/same))
# 	:mod (a/all)
# 	:manner (u/up)))
#
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: starting at row three column three
# Speech AMR:
#  (s/start-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/be-located-at-91
# 		:ARG1 (a/and
# 			:op1 (r/row
# 				:ord (t/third))
# 			:op2 (c/column
# 				:ord 3))))
#
# Example 2:
# Sentence: yeah great
# Speech AMR:
#  (y/yeah)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (i/implicate-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/top
# 		:polarity -))
#
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: that one okay
# Speech AMR:
#  (o/one
# 	:mod (t/that))
#
# Gesture label(s):
# head: nod;
# body: move, left;
# body: still;
# RA: move, right; RH: into closed, front;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/side)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: block the goes on top of the block you just placed but not totally centered
# Speech AMR:
#  (i/implicit-predicate-00
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another)
# 		:ARG1-of (b2/be-located-at-91
# 			:ARG2 (c/contrast-01
# 				:ARG1 (o/on
# 					:op1 (t/top
# 						:poss b
# 						:ARG1-of (p/place-01
# 							:ARG0 b
# 							:time (j/just))))
# 				:ARG2 (c2/center-01
# 					:polarity -
# 					:mod (t2/total))))))
#
# Gesture label(s):
# body: still;
# LA: move, up; LH: into point, front;
# body: still;
# body: move, down; arms: move, down; hands: into open, back down;
# body: still;
# head: rotate;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into open, back;
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a2/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (t/tower)
# 		:ARG2 a2))
#
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and one block on the right side of the first block and move back a bit
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 1
# 		:location (o/on
# 			:op1 (s/side
# 				:ARG1-of (r/right-04)
# 				:poss (b2/block
# 					:ord (o2/ordinal-entity
# 						:value 1)))))
# 	:op3 (m/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:direction (b3/back
# 			:degree (b4/bit))))
#
# Gesture label(s):
# Unknown
# Rh: into fist, back;
# body: still;
# Unknown
# hands: into facing, left;
# arms: beckon;
# body: still;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (b/backward))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: take one block put it on top of those two in the middle
# Speech AMR:
#  (a/and
# 	:op1 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:quant 1))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 b
# 		:ARG2 (o/on-top-of
# 			:op1 (b2/block
# 				:mod (t2/that)
# 				:quant 2
# 				:location (m/middle)))))
#
# Gesture label(s):
# RA: move, up; RH: into one, front;
# RA: move, front; RH: into L, down;
# RA: move, up; RH: L, down;
# RA: move, back;
# body: still;
# RA: move, down; RH: into point, down;
# LA: move, left; LH: into L, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into open, back;
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a2/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (t/tower)
# 		:ARG2 a2))
# Speech AMR:
#  (i/implicate-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/top
# 		:polarity -))

# %%
random.seed(12)

final_all_results = []
prompts = ulla.generate_prompt(df_test, examples)
total_prompts = len(prompts)
for prompt in tqdm(prompts, total=total_prompts, desc="Processing", unit="row"):
    call_llama = ulla.query_LLM_multiple(client, prompt["prompt"], temp=0.3, n=3)
    final_all_results.append({
        "prompt": prompt["prompt"],
        "sentence": prompt["meta"]["sentence"],
        "scenario": prompt["meta"]["scenario"],
        "file": prompt["meta"]["file"],
        "llama_1": call_llama[0],
        "llama_2": call_llama[1],
        "llama_3": call_llama[2]
    })
# Out:
# Processing: 100%|██████████| 198/198 [5:54:56<00:00, 107.56s/row]

# %%
## Official run
last_results_llama = 'last_results_llama.pkl'
pickle.dump(final_all_results, open(last_results_llama, 'wb'))

# %%
## Open the FINAL results
last_results_llama = 'last_results_llama.pkl'
official_results = pickle.load(open(last_results_llama, 'rb'))

# %%
## Print the results from the official run. You can play around with what you want to print.
## You can look up specific sentences to see Llama's output for example.
for item in official_results:
    print(f"Sentence: {item['sentence']}\nScenario: {item['scenario']}\nPrompt:\n{item['prompt']}") 
    # print(llama 1:\n{item['llama_1']}\nllama 2:\n{item['llama_2']}\nllama 3:\n{item['llama_3']}")
    print(120*"-")
# Out:
# Sentence: so put put a block on the back block good
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay
# Speech AMR:
#  (o/okay-04)
#
# Example 2:
# Sentence: space two out a little less than a block length
# Speech AMR:
#  (s/space-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/implicit-role
# 		:quant 2)
# 	:ARG2 (q/distance-quantity
# 		:unit (b/block)
# 		:ARG1-of (h/have-quant-91
# 			:ARG2 1
# 			:ARG3 (l/less
# 				:mod (l2/little)))))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1)
# 	:ARG2 (b2/block
# 		:mod (b3/back)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: so put put a block on the back block good
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: four blocks in the front okay
# Speech AMR:
#  (b/block
# 	:quant 4
# 	:location (i/in
# 		:op1 (f/front)))
#
# Gesture label(s):
# arms: shake, left; hands: into claw, down;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (r/row)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: it cannot fall down from the ground right
# Speech AMR:
#  (p/possible-01
# 	:polarity -
# 	:ARG1 (f/fall-01
# 		:ARG1 (i/it)
# 		:ARG3 (g/ground))
# 	:ARG1-of (r/request-confirmation-91))
#
# Gesture label(s):
# head: shake; hands: rotate, open, up;
# Unknown
# LA: move, down; LH: into point, front;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: point, front;
# RA: move, down; RH: into claw, down;
# RA: move, up; RH: into point, front;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: so put put a block on the back block good
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: five blocks to start
# Speech AMR:
#  (b/block
# 	:quant 5
# 	:ARG1-of (s/start-01))
#
# Gesture label(s):
# body: move, left;
# body: still;
# LH: into open, up;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: now these are a little jiggled
# Speech AMR:
#  (j/jiggle-01
# 	:ARG1 (t/these)
# 	:mod (l/little))
#
# Gesture label(s):
# head: nod; LA: move, back;
# RA: move, up; RH: shake, down, open;
# RA: move, front; RH: into point, down;
#
# Gesture AMR:
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (j/jiggle-01)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: point, front;
# RA: move, down; RH: into claw, down;
# RA: move, up; RH: into point, front;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1)
# 	:ARG2 (b2/block
# 		:mod (b3/back)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: put two blocks
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: you're done
# Speech AMR:
#  (d/done-08
# 	:ARG0 (y/you))
#
# Example 2:
# Sentence: put a bit a bit right uh
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG2 (r/right-04
# 		:degree (b/bit)))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 2))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: put two blocks
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: it starts in the top left
# Speech AMR:
#  (s/start-01
# 	:ARG0 (i/it)
# 	:location (i2/in
# 		:op1 (l/left
# 			:mod (t/top))))
#
# Gesture label(s):
# Unknown
# LH: into claw, down;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: same direction that that's pushed off yea alright
# Speech AMR:
#  (s/same-01
# 	:ARG2 (p/push-01
# 		:ARG1 (t/that)
# 		:ARG2 (o/off))
# 	:ARG3 (d/direction))
#
# Gesture label(s):
# RA: move, down; RH: into open, down;
# arms: move, up, into gap, left; hands: into facing, left, into claw, left;
# LA: move, left;
# arms: move, down; hands: into open, down;
# head: rotate;
#
# Gesture AMR:
# (d/deixis-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/left)
# 	:ARG2 (a/actor))
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/slide
# 			:direction (l/left))
# 		:ARG2 (a2/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (b/block)
# 		:ARG2 a2))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, gap, left; hands: claw, down;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: put two blocks
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: it's gonna be a pyramid from three of the rows of two
# Speech AMR:
#  (p/pyramid
# 	:consist-of (r/row
# 		:quant 3
# 		:consist-of (r2/row
# 			:quant 2))
# 	:domain (i/it))
#
# Gesture label(s):
# body: move, front; LA: move, down;
# body: move, front; arms: into gap, left; hands: facing, into open;
# arms: move, down;
# RA: move, left;
# RA: shake, right;
# RA: move, down;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (d/deixis-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (l/location)
# 			:ARG2 (a2/actor))
# 		:op2 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (p/put-01)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)
# 		:op2 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01)
# 			:ARG2 a2)))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Example 2:
# Sentence: then they connect to the two wider blocks
# Speech AMR:
#  (c/connect-01
# 	:time (t/then)
# 	:ARG1 (t2/they)
# 	:ARG2 (b/block
# 		:quant 2
# 		:mod (w/wide
# 			:degree (m/more))))
#
# Gesture label(s):
# Unknown
# arms: move, up; hands: to face;
# arms: move, front; hands: into point, front;
# Unknown
# arms: move, down;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (a/and
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (b/block)
# 		:ARG2 (a2/actor))
# 	:op2 (d2/deixis-GA
# 		:ARG0 s
# 		:ARG1 (b2/block)
# 		:ARG2 a2))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, gap, left; hands: claw, down;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 2))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: um
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: okay
# Speech AMR:
#  (o/okay-04)
#
# Example 2:
# Sentence: get another one stacked on top
# Speech AMR:
#  (g/get-04
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (s/stack-01
# 		:ARG1 (o/one
# 			:mod (a/another))
# 		:ARG2 (o2/on
# 			:op1 (t/top))))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (u/um
# 	:mode expressive)
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: um
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: move that block uh
# Speech AMR:
#  (m/move-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (t/that)))
#
# Gesture label(s):
# LA: move, right; LH: claw, right;
# LH: rotate, claw, front;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: they’re in other words are not perfectly clear
# Speech AMR:
#  (c/clear-06
# 	:manner (w/words
# 		:mod (o/other))
# 	:ARG1 (t/they)
# 	:polarity -
# 	:ARG1-of (p/perfect-02))
#
# Gesture label(s):
# Unknown
# body: still;
# hands: enough;
#
# Gesture AMR:
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (k/know-01
# 		:polarity -)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (e2/enough)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: rotate, gap, left; hands: claw, down;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: um
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: them towards you
# Speech AMR:
#  (o/orient-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/them
# 		:location (t2/towards
# 			:op1 y)))
#
# Gesture label(s):
# hands: claw, down; LA: move, back; RA: move, front;
# hands: claw, down; LA: move, front; RA: move, back;
# hands: claw, down; LA: move, back; RA: move, front;
# hands: into closed, back; RA: move, back;
# arms: move, front, into gap, left; hands: facing, into closed;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (b/block)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01)
# 		:ARG2 a))
#
# Example 2:
# Sentence: then you going to have a fourth block
# Speech AMR:
#  (h/have-03
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:ord 4))
#
# Gesture label(s):
# body: move, right; RA: move, up; RH: to face;
# body: move, left; RA: move, down;
# LA: move, up; LH: into point, front;
# LA: move, down; LH: into open, right;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: rotate, gap, left; hands: claw, down;
# Gesture AMR:
# (a/and
# 	:op1 (g2/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 (s/signaler)
# 			:ARG1 (p/put-01
# 				:ARG1 (b/block))
# 			:ARG2 (a2/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l/location)
# 			:ARG2 a2))
# 	:op2 (g/gesture-unit
# 		:op1 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (p2/put-01
# 				:ARG1 (b2/block))
# 			:ARG2 a2)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (l2/location)
# 			:ARG2 a2)))
# Speech AMR:
#  (u/um
# 	:mode expressive)
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then put one on the top
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: just one
# Speech AMR:
#  (i/implicit-role
# 	:quant 1)
#
# Example 2:
# Sentence: and go
# Speech AMR:
#  (a/and)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (a/and
# 	:op2 (p/put-01
# 		:mode imperative
# 		:time (t/then)
# 		:ARG0 (y/you)
# 		:ARG1 (o/one)
# 		:ARG2 (o2/on
# 			:op1 (t2/top))))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then put one on the top
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the base is going to have four second one’s going to have three then two on top of that and then one
# Speech AMR:
#  (a/and
# 	:op1 (h/have-03
# 		:ARG0 (b/base)
# 		:ARG1 (i/implicit-role
# 			:quant 4))
# 	:op2 (h2/have-03
# 		:ARG0 (i2/implicit-role
# 			:ord (o/ordinal-entity
# 				:value 2))
# 		:ARG1 (i3/implicit-role
# 			:quant 3))
# 	:op3 (i4/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i5/implicit-role
# 			:quant 2)
# 		:destination (o2/on-top-of
# 			:op1 (t/that)))
# 	:op4 (i6/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (i7/implicit-role
# 			:quant 1)))
#
# Gesture label(s):
# RA: move, up; RH: into four, front;
# RH: into three;
# RA: move, up; RH: into two;
# RH: into one;
# RA: move, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 4
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 3
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 2
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: start off with just a block and then put a block on top of
# Speech AMR:
#  (a/and
# 	:op1 (s/start-off-2
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:mod (j/just)))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (b2/block)
# 		:ARG2 (o/on
# 			:op1 (t/top
# 				:op1 (t2/that)))
# 		:time (t3/then)))
#
# Gesture label(s):
#     arms: move, up, into gap, left; hands: into facing, left, into claw, left;
#     head: move, down;
# head: move, up; arms: move, down; hands: into open, down;
# body: move, up; RH: tap;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/top)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, up; RH: into point, front;
# Unknown
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then put one on the top
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: stack stack it up no
# Speech AMR:
#  (s/stack-up-03
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/it))
#
# Gesture label(s):
# body: still;
# LA: move, up; LH: into open, right;
# arms: together, left; hands: into contact, left, into closed, left;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-10)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: stack three blocks on one side yup
# Speech AMR:
#  (s/stack-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 3)
# 	:ARG2 (o/on
# 		:op1 (s2/side
# 			:quant 1)))
#
# Gesture label(s):
# Unknown
# RA: move, right; RH: into point, down;
# RH: tap, point;
# RA: move, up; RH: into claw, front;
# RA: move, down;
# LA: move, to hip;
# body: still;
# head: nod;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/stack-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, up; RH: into point, front;
# Unknown
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (a/and
# 	:op2 (p/put-01
# 		:mode imperative
# 		:time (t/then)
# 		:ARG0 (y/you)
# 		:ARG1 (o/one)
# 		:ARG2 (o2/on
# 			:op1 (t2/top))))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no that doesn't look like it’s going to work
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: like about a third of a block a part so more close in than that
# Speech AMR:
#  (l/like-04
# 	:ARG2 (q/distance-quantity
# 		:mod (a/about)
# 		:unit (b/block
# 			:ARG1-of (h/have-quant-91
# 				:ARG2 (t/third)))
# 		:mod (a2/apart))
# 	:ARG2-of (i/infer-01
# 		:ARG1 (h2/have-degree-91
# 			:ARG2 (c/close-10)
# 			:ARG3 (m/more)
# 			:ARG4 (t2/that))))
#
# Example 2:
# Sentence: four blocks
# Speech AMR:
#  (b/block
# 	:quantity 4)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (l/look-02
# 		:ARG0 (t/that)
# 		:ARG1 (w/work-09)
# 		:polarity -))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no that doesn't look like it’s going to work
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: great yep
# Speech AMR:
#  (g/great)
#
# Gesture label(s):
# hands: thumb, up;
# head: nod;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/good)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: seven blocks in a row
# Speech AMR:
#  (i/implicit-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 7)
# 	:manner (r/row))
#
# Gesture label(s):
# Unknown
# arms: move, up; LH: into two, front; RH: into five, front;
# LA: move, down; RA: move, right; RH: closed, down;
# RA: move, back;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 7
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/place-01)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down; hands: into claw, down;
# body: still;
# arms: move, up; hands: into claw, down;
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/grab-01
# 		:ARG1 (b/block
# 			:quant 2))
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-06)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no that doesn't look like it’s going to work
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and then three more coming off from the other direction touching the corner okay
# Speech AMR:
#  (a/and
# 	:op2 (i/implicit-role
# 		:quant 3
# 		:mod (m/more)
# 		:ARG1-of (c/come-33
# 			:ARG3 (f/from
# 				:op1 (d/direction
# 					:mod (o/other)))
# 			:mod (o2/off))
# 		:ARG0-of (t/touch-01
# 			:ARG1 (c2/corner))
# 		:time (t2/then)))
#
# Gesture label(s):
# body: still;
# LA: move, left; LH: into closed, front;
# body: still;
# head: nod; LA: move, right; LH: into closed, right;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (d/direction)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: and then the second block goes on top of that
# Speech AMR:
#  (g/go-01
# 	:ARG1 (b/block
# 		:ord (o/ordinal-entity
# 			:value 2);ARG4(o2/on
# 			:op1 (t/top
# 				:location (t2/that)))))
#
# Gesture label(s):
# RA: move, up;
# RA: move, down; RH: into open, left;
# RA: rotate
# body: still;
# hands: rotate;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (p/put-01)
# 			:ARG2 a2)
# 		:op2 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (r/rotate-01)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i3/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower)
# 			:ARG2 a2)
# 		:op2 (i4/icon-GA
# 			:ARG0 s
# 			:ARG1 (r2/rotate-01)
# 			:ARG2 a2)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down; hands: into claw, down;
# body: still;
# arms: move, up; hands: into claw, down;
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/grab-01
# 		:ARG1 (b/block
# 			:quant 2))
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-06)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (l/look-02
# 		:ARG0 (t/that)
# 		:ARG1 (w/work-09)
# 		:polarity -))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: yes
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: starting at row three column three
# Speech AMR:
#  (s/start-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/be-located-at-91
# 		:ARG1 (a/and
# 			:op1 (r/row
# 				:ord (t/third))
# 			:op2 (c/column
# 				:ord 3))))
#
# Example 2:
# Sentence: yeah great
# Speech AMR:
#  (y/yeah)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (y/yes)
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: yes
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: closest to the middle yeah
# Speech AMR:
#  (h/have-degree-91
# 	:ARG2 (c/close-10
# 		:ARG2 (m/middle))
# 	:ARG3 (m2/most))
#
# Gesture label(s):
# body: still;
# head: nod;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-10)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: gonna have another block right next to that block so it’d be over the space of those two bottom blocks
# Speech AMR:
#  (h/have-02
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another))
# 	:location (n/next-to
# 		:ARG1 (t/that)
# 		:mod (r/right))
# 	:purpose (b2/be-located-at-91
# 		:ARG1 b
# 		:ARG2 (o/over
# 			:op1 (s/space
# 				:poss (b3/block
# 					:mod (t/that)
# 					:location (b4/bottom))))))
#
# Gesture label(s):
# RA: move, up; RH: into open, left;
# RA: move, right;
# LA: move, front; RA: move, down; hands: into open, back;
# head: move, right;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/space)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# body: still;
# RA: move, up; RH: claw, down;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: yes
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and one block on the right side of the first block and move back a bit
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 1
# 		:location (o/on
# 			:op1 (s/side
# 				:ARG1-of (r/right-04)
# 				:poss (b2/block
# 					:ord (o2/ordinal-entity
# 						:value 1)))))
# 	:op3 (m/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:direction (b3/back
# 			:degree (b4/bit))))
#
# Gesture label(s):
# Unknown
# Rh: into fist, back;
# body: still;
# Unknown
# hands: into facing, left;
# arms: beckon;
# body: still;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (b/backward))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: take one block put it on top of those two in the middle
# Speech AMR:
#  (a/and
# 	:op1 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:quant 1))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 b
# 		:ARG2 (o/on-top-of
# 			:op1 (b2/block
# 				:mod (t2/that)
# 				:quant 2
# 				:location (m/middle)))))
#
# Gesture label(s):
# RA: move, up; RH: into one, front;
# RA: move, front; RH: into L, down;
# RA: move, up; RH: L, down;
# RA: move, back;
# body: still;
# RA: move, down; RH: into point, down;
# LA: move, left; LH: into L, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# body: still;
# RA: move, up; RH: claw, down;
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (y/yes)
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: so jiggle the go
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the block you have in your left hand or in your hands goes in between that diagonal shape yep
# Speech AMR:
#  (g/go-35
# 	:ARG1 (b/block
# 		:ARG1-of (h/have-03
# 			:ARG0 (y/you)
# 			:location (i/in
# 				:op1 (h2/hand
# 					:poss y))))
# 	:ARG2 (i2/in
# 		:op1 (b2/between
# 			:op1 (s/shape
# 				:mod (t/that)
# 				:mod (d/diagonal)))))
#
# Example 2:
# Sentence: and uh two blocks
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 2))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (j/jiggle-01
# 	:mode imperative
# 	:ARG0 (y/you))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: so jiggle the go
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: more great
# Speech AMR:
#  (m/more)
#
# Gesture label(s):
# hands: shake, left;
# Unknown
# hands: into fist, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: spread them apart a little bit but not as wide as a full block
# Speech AMR:
#  (s/spread-03
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/them)
# 	:direction (a/apart
# 		:quant (b/bit
# 			:mod (l/little))
# 		:quant (l2/less-than
# 			:op1 (q/distance-quantity
# 				:unit (b2/block)
# 				:quant 1))))
#
# Gesture label(s):
# arms: move, into gap, left; hands: facing, closed;
# body: still;
# arms: move, back;
# RA: move, up; RH: into one, front;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/spread-03
# 		:direction (a/apart))
# 	:ARG2 (a2/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: into point, down;
# RH: shake, down;
# RH: into point, front;
# Unknown
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (c/count-01
# 			:ARG2 (a/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: so jiggle the go
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: all right put a block down
# Speech AMR:
#  (p/put-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 1
# 		:direction (d/down))
# 	:mod (a/all-right))
#
# Gesture label(s):
# RA: move, front left; RH: into claw, down;
# body: still;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (p/put-01)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Example 2:
# Sentence: ever so slightly alright
# Speech AMR:
#  (s/slight
# 	:degree (s2/so
# 		:mod (e/ever)))
#
# Gesture label(s):
# body: still;
# hands: into open, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (r/right))
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RA: move, front; RH: into point, down;
# RH: shake, down;
# RH: into point, front;
# Unknown
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:mode expressive
# 		:ARG0 (s/signaler)
# 		:ARG1 (j/jiggle-01)
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d1/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b2/block)
# 			:ARG2 a)))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (c/count-01
# 			:ARG2 (a/actor))
# 		:op2 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
# Speech AMR:
#  (j/jiggle-01
# 	:mode imperative
# 	:ARG0 (y/you))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: good enough
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: then a last block on the crack of those two blocks
# Speech AMR:
#  (i/implicit-predicate-00
# 	:ARG1 (b/block
# 		:mod (l/last))
# 	:location (o/on
# 		:op1 (c/crack
# 			:poss (b2/block
# 				:quant 2
# 				:mod (t/that)))))
#
# Example 2:
# Sentence: and then take the two on top
# Speech AMR:
#  (a/and
# 	:op2 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/implicit-role
# 			:quant 2
# 			:location (o/on
# 				:op1 (t2/top))))
# 	:mod (t3/then))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (e/enough-01
# 	:ARG2 (g/good))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: good enough
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: this one looks like a (oh sorry) this one looks like a smiley face
# Speech AMR:
#  (l/look-02
# 	:ARG0 (o/one
# 		:mod (t/this))
# 	:ARG1 (l2/like-04
# 		:ARG2 (f/face
# 			:mod (s/smiley))))
#
# Gesture label(s):
# Unknown
# body: move, front;
# body: move, back; hands: rotate;
# arms: move, up; hands: to face;
# arms: into gap, left; hands: into claw, down;
#
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (p/put-01)
# 		:ARG2 (a2/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p2/put-01)
# 		:ARG2 a2))
#
# Example 2:
# Sentence: and there's one touching that block's bottom corner
# Speech AMR:
#  (t/touch-01
# 	:ARG0 (i/implicit-role
# 		:quant 1)
# 	:ARG1 (c/corner
# 		:mod (b/bottom)
# 		:poss (b2/block
# 			:mod (t2/that))))
#
# Gesture label(s):
# body: still;
# hands: into point, down;
# arms: together, left; hands: into claw, down;
# RA: move, right; RH: into claw, down;
# RH: into open, down;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (m/move-01)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, up; hands: into open, front;
# body: move, back; arms: move, down;
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: good enough
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: then the gap should be a little less of between him
# Speech AMR:
#  (b/be-03
# 	:ARG0 (g/gap)
# 	:degree (l/less
# 		:mod (l2/little))
# 	:mod (b2/between
# 		:ARG1 (t/them)))
#
# Gesture label(s):
# arms: move, up; hands: facing, into gap, left;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/less)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/squeeze
# 		:direction (t/together))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: almost like that
# Speech AMR:
#  (l/like-04
# 	:ARG1 (t/that)
# 	:mod (a/almost))
#
# Gesture label(s):
# Unknown
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (r/rotate-01)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, up; hands: into open, front;
# body: move, back; arms: move, down;
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (e/enough-01
# 	:ARG2 (g/good))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then jiggle the two in front of them
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: i want you to tilt all of them so that the one corner is touching
# Speech AMR:
#  (w/want-01
# 	:ARG0 (i/I)
# 	:ARG1 (t/tilt-01
# 		:ARG0 (y/you)
# 		:ARG1 (t2/them
# 			:mod (a/all))
# 		:purpose (t3/touch-01
# 			:ARG0 (c/corner
# 				:quant 1))))
#
# Example 2:
# Sentence: it kind of goes down diagonally or so in yours
# Speech AMR:
#  (g/go-06
# 	:ARG0 (i/it)
# 	:ARG2 (d/down)
# 	:manner (a/about
# 		:op1 (d2/diagonal))
# 	:location (i2/in
# 		:op1 (i3/implicit-role
# 			:poss (y/you)))
# 	:degree (k/kind-of))
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (a/and
# 	:op1 (j/jiggle-01
# 		:time (t/then)
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/implicit-role
# 			:quant 2
# 			:location (f/front
# 				:poss (t2/them)))))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then jiggle the two in front of them
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and it's turned at an angle
# Speech AMR:
#  (t/turn-01
# 	:ARG1 (i/it)
# 	:destination (a2/angle))
#
# Gesture label(s):
# hands: rotate;
# body: still;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (p/put-01)
# 			:ARG2 a2)
# 		:op2 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (r/rotate-01)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i3/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower)
# 			:ARG2 a2)
# 		:op2 (i4/icon-GA
# 			:ARG0 s
# 			:ARG1 (r2/rotate-01)
# 			:ARG2 a2)))
#
# Example 2:
# Sentence: place it such that they are like interleaving
# Speech AMR:
#  (p/place-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/it)
# 	:cause-of (i2/interleave-01
# 		:ARG1 (t/they)))
#
# Gesture label(s):
# LH: rotate; RH: shake, left;
# hands: shake;
# arms: apart, left, into gap, left; hands: into claw, left, into facing, left; RA: move, right;
# arms: together, left;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (i2/interleave-01)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# hands: shake, closed;
# hands: shake, front, into point, down;
# arms: move, down;
# Gesture AMR:
# (i/icon-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (j/jiggle-01)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/slide-01
# 			:direction (f/forward))
# 		:ARG2 (a/actor))
# 	:op2 (a1/and
# 		:op1 (d/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b1/block)
# 			:ARG2 a)
# 		:op2 (d2/deixis-GA
# 			:ARG0 s
# 			:ARG1 (b/block)
# 			:ARG2 a)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then jiggle the two in front of them
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: ah now uh move it so it's on the front front one and the one you just put it on
# Speech AMR:
#  (m/multi-sentence
# 	:snt1 (n/no)
# 	:snt2 (m2/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i/it)
# 		:purpose (b/be-located-at-91
# 			:ARG1 i
# 			:ARG2 (a/and
# 				:op1 (o/one
# 					:mod (f/front))
# 				:op2 (o2/one
# 					:ARG2-of (p/put-01
# 						:ARG0 y
# 						:time (j/just)))))))
#
# Gesture label(s):
# RA: move, up right; RH: into closed, left;
# RA: move, left; RH: closed, left;
# RA: move, front; RH: into point, front;
# RA: move, down back; RH: point, down;
# RA: move, front right; RH: point, down;
# body: still;
# RA: move, up; RH: into claw, front;
#
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (m/move-01
# 			:direction (f/front))
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/turn
# 		:ARG1 (b/block))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: like they're all stacked right on top of each other
# Speech AMR:
#  (l/like-04
# 	:ARG1 (t/they)
# 	:ARG2 (s/stack-01
# 		:quant (a/all)
# 		:destination (r/right
# 			:op1 (t2/top
# 				:quant (e/each-other)))))
#
# Gesture label(s):
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
# arms: move, up; hands: into closed, back;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/stack-01)
# 	:ARG2 (a/actor))
#
# ...
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: the base is going to have four second one’s going to have three then two on top of that and then one
# Speech AMR:
#  (a/and
# 	:op1 (h/have-03
# 		:ARG0 (b/base)
# 		:ARG1 (i/implicit-role
# 			:quant 4))
# 	:op2 (h2/have-03
# 		:ARG0 (i2/implicit-role
# 			:ord (o/ordinal-entity
# 				:value 2))
# 		:ARG1 (i3/implicit-role
# 			:quant 3))
# 	:op3 (i4/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (i5/implicit-role
# 			:quant 2)
# 		:destination (o2/on-top-of
# 			:op1 (t/that)))
# 	:op4 (i6/implicit-predicate-00
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (i7/implicit-role
# 			:quant 1)))
#
# Gesture label(s):
# RA: move, up; RH: into four, front;
# RH: into three;
# RA: move, up; RH: into two;
# RH: into one;
# RA: move, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 4
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 3
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 2
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: start off with just a block and then put a block on top of
# Speech AMR:
#  (a/and
# 	:op1 (s/start-off-2
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:mod (j/just)))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 (b2/block)
# 		:ARG2 (o/on
# 			:op1 (t/top
# 				:op1 (t2/that)))
# 		:time (t3/then)))
#
# Gesture label(s):
#     arms: move, up, into gap, left; hands: into facing, left, into claw, left;
#     head: move, down;
# head: move, up; arms: move, down; hands: into open, down;
# body: move, up; RH: tap;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (t/top)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
# arms: shake, left;
# arms: rotate; hands: into opposed, left, into open, left;
# Gesture AMR:
# (d/deixis-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then you got two towers like that on the sides
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: stack stack it up no
# Speech AMR:
#  (s/stack-up-03
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (i/it))
#
# Gesture label(s):
# body: still;
# LA: move, up; LH: into open, right;
# arms: together, left; hands: into contact, left, into closed, left;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (b/block)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-10)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: stack three blocks on one side yup
# Speech AMR:
#  (s/stack-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 3)
# 	:ARG2 (o/on
# 		:op1 (s2/side
# 			:quant 1)))
#
# Gesture label(s):
# Unknown
# RA: move, right; RH: into point, down;
# RH: tap, point;
# RA: move, up; RH: into claw, front;
# RA: move, down;
# LA: move, to hip;
# body: still;
# head: nod;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/stack-01)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (o/ok)
# 	:ARG2 (a/actor))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# arms: move, down, into gap, left; hands: into facing, left, into closed, left;
# arms: shake, left;
# arms: rotate; hands: into opposed, left, into open, left;
# Gesture AMR:
# (d/deixis-GA
# 	:mode expressive
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# Speech AMR:
#  (g/get-01
# 	:ARG0 (y/you)
# 	:ARG1 (t/tower
# 		:quantity 2
# 		:location (o/on
# 			:op1 (s/sides))))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then you do that same process all the way up
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: like about a third of a block a part so more close in than that
# Speech AMR:
#  (l/like-04
# 	:ARG2 (q/distance-quantity
# 		:mod (a/about)
# 		:unit (b/block
# 			:ARG1-of (h/have-quant-91
# 				:ARG2 (t/third)))
# 		:mod (a2/apart))
# 	:ARG2-of (i/infer-01
# 		:ARG1 (h2/have-degree-91
# 			:ARG2 (c/close-10)
# 			:ARG3 (m/more)
# 			:ARG4 (t2/that))))
#
# Example 2:
# Sentence: four blocks
# Speech AMR:
#  (b/block
# 	:quantity 4)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (d/do-02
# 	:ARG0 (y/you)
# 	:ARG1 (p/process
# 		:mod (s/same))
# 	:mod (a/all)
# 	:manner (u/up)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then you do that same process all the way up
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: great yep
# Speech AMR:
#  (g/great)
#
# Gesture label(s):
# hands: thumb, up;
# head: nod;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (g/good)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: seven blocks in a row
# Speech AMR:
#  (i/implicit-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:quant 7)
# 	:manner (r/row))
#
# Gesture label(s):
# Unknown
# arms: move, up; LH: into two, front; RH: into five, front;
# LA: move, down; RA: move, right; RH: closed, down;
# RA: move, back;
#
# Gesture AMR:
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 7
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (r/row)
# 		:ARG2 (a/actor))
# 	:op2 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/place-01)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into point, left;
# RA: rotate, into point, left;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01
# 			:mod (u/up))
# 		:ARG2 a2)
# 	:op1 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r2/rotate-01)
# 		:ARG2 a2))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: and then you do that same process all the way up
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and then three more coming off from the other direction touching the corner okay
# Speech AMR:
#  (a/and
# 	:op2 (i/implicit-role
# 		:quant 3
# 		:mod (m/more)
# 		:ARG1-of (c/come-33
# 			:ARG3 (f/from
# 				:op1 (d/direction
# 					:mod (o/other)))
# 			:mod (o2/off))
# 		:ARG0-of (t/touch-01
# 			:ARG1 (c2/corner))
# 		:time (t2/then)))
#
# Gesture label(s):
# body: still;
# LA: move, left; LH: into closed, front;
# body: still;
# head: nod; LA: move, right; LH: into closed, right;
# body: still;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (d/direction)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: and then the second block goes on top of that
# Speech AMR:
#  (g/go-01
# 	:ARG1 (b/block
# 		:ord (o/ordinal-entity
# 			:value 2);ARG4(o2/on
# 			:op1 (t/top
# 				:location (t2/that)))))
#
# Gesture label(s):
# RA: move, up;
# RA: move, down; RH: into open, left;
# RA: rotate
# body: still;
# hands: rotate;
#
# Gesture AMR:
# (a/and
# 	:op1 (g/gesture-unit
# 		:op1 (i/icon-GA
# 			:ARG0 s
# 			:ARG1 (p/put-01)
# 			:ARG2 a2)
# 		:op2 (i2/icon-GA
# 			:ARG0 s
# 			:ARG1 (r/rotate-01)
# 			:ARG2 a2))
# 	:op2 (g2/gesture-unit
# 		:op1 (i3/icon-GA
# 			:ARG0 s
# 			:ARG1 (t/tower)
# 			:ARG2 a2)
# 		:op2 (i4/icon-GA
# 			:ARG0 s
# 			:ARG1 (r2/rotate-01)
# 			:ARG2 a2)))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into point, left;
# RA: rotate, into point, left;
# body: still;
# Gesture AMR:
# (a/and
# 	:op1 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (r/rotate-01
# 			:mod (u/up))
# 		:ARG2 a2)
# 	:op1 (i2/icon-GA
# 		:ARG0 s
# 		:ARG1 (r2/rotate-01)
# 		:ARG2 a2))
# Speech AMR:
#  (d/do-02
# 	:ARG0 (y/you)
# 	:ARG1 (p/process
# 		:mod (s/same))
# 	:mod (a/all)
# 	:manner (u/up)))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no on top yeah
# Scenario: speech
# Prompt:
# Given the following speech Abstract Meaning Representation (AMR), generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: starting at row three column three
# Speech AMR:
#  (s/start-01
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (b/be-located-at-91
# 		:ARG1 (a/and
# 			:op1 (r/row
# 				:ord (t/third))
# 			:op2 (c/column
# 				:ord 3))))
#
# Example 2:
# Sentence: yeah great
# Speech AMR:
#  (y/yeah)
#
# Now, generate a sentence from the following speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Speech AMR:
#  (i/implicate-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/top
# 		:polarity -))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no on top yeah
# Scenario: gesture
# Prompt:
# Given the following gesture label(s) and gesture Abstract Meaning Representation (AMR), generate a corresponding sentence and speech AMR in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: closest to the middle yeah
# Speech AMR:
#  (h/have-degree-91
# 	:ARG2 (c/close-10
# 		:ARG2 (m/middle))
# 	:ARG3 (m2/most))
#
# Gesture label(s):
# body: still;
# head: nod;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (c/close-10)
# 	:ARG2 (a/actor))
# (e/emblem-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (y/yes)
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: gonna have another block right next to that block so it’d be over the space of those two bottom blocks
# Speech AMR:
#  (h/have-02
# 	:ARG0 (y/you)
# 	:ARG1 (b/block
# 		:mod (a/another))
# 	:location (n/next-to
# 		:ARG1 (t/that)
# 		:mod (r/right))
# 	:purpose (b2/be-located-at-91
# 		:ARG1 b
# 		:ARG2 (o/over
# 			:op1 (s/space
# 				:poss (b3/block
# 					:mod (t/that)
# 					:location (b4/bottom))))))
#
# Gesture label(s):
# RA: move, up; RH: into open, left;
# RA: move, right;
# LA: move, front; RA: move, down; hands: into open, back;
# head: move, right;
# body: still;
#
# Gesture AMR:
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (d/deixis-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (l/location)
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (i/icon-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (s2/space)
# 		:ARG2 (a/actor))
# 	:op2 (d/deixis-GA
# 		:ARG0 s
# 		:ARG1 (l/location)
# 		:ARG2 a))
#
# Now, generate a sentence and the corresponding speech AMR from the following gesture label(s) and gesture AMR and explain your reasoning. Please provide the output only in json format. The speech AMR should be on one line:
# [{"sentence": "Your generated sentence here.", "speech AMR:" "Your generated speech AMR here", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into open, back;
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a2/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (t/tower)
# 		:ARG2 a2))
#
# ------------------------------------------------------------------------------------------------------------------------
# Sentence: no on top yeah
# Scenario: speech_gesture
# Prompt:
# Given the following gesture label(s), gesture Abstract Meaning Representation (AMR) and speech AMR, generate a corresponding sentence in natural spoken English. Provide a short explanation. First, read the examples to understand the Abstract Meaning Representation format:
#
# Example 1:
# Sentence: and one block on the right side of the first block and move back a bit
# Speech AMR:
#  (a/and
# 	:op2 (b/block
# 		:quant 1
# 		:location (o/on
# 			:op1 (s/side
# 				:ARG1-of (r/right-04)
# 				:poss (b2/block
# 					:ord (o2/ordinal-entity
# 						:value 1)))))
# 	:op3 (m/move-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:direction (b3/back
# 			:degree (b4/bit))))
#
# Gesture label(s):
# Unknown
# Rh: into fist, back;
# body: still;
# Unknown
# hands: into facing, left;
# arms: beckon;
# body: still;
# Unknown
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 (s2/slide-01
# 		:direction (b/backward))
# 	:ARG2 (a/actor))
#
# Example 2:
# Sentence: take one block put it on top of those two in the middle
# Speech AMR:
#  (a/and
# 	:op1 (t/take-01
# 		:mode imperative
# 		:ARG0 (y/you)
# 		:ARG1 (b/block
# 			:quant 1))
# 	:op2 (p/put-01
# 		:mode imperative
# 		:ARG0 y
# 		:ARG1 b
# 		:ARG2 (o/on-top-of
# 			:op1 (b2/block
# 				:mod (t2/that)
# 				:quant 2
# 				:location (m/middle)))))
#
# Gesture label(s):
# RA: move, up; RH: into one, front;
# RA: move, front; RH: into L, down;
# RA: move, up; RH: L, down;
# RA: move, back;
# body: still;
# RA: move, down; RH: into point, down;
# LA: move, left; LH: into L, down;
#
# Gesture AMR:
# (i/icon-GA
# 	:ARG0 (s/signaler)
# 	:ARG1 1
# 	:ARG2 (a/actor))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (p/put-01)
# 		:ARG2 a))
#
# Now, generate a sentence from the following gesture label(s), gesture AMR and speech AMR and explain your reasoning. Please provide the output only in json format:
# [{"sentence": "Your generated sentence here.", "explanation": "Your explanation here."}]
# Gesture label(s):
# RH: rotate, into open, back;
# Gesture AMR:
# (g/gesture-unit
# 	:op1 (d/deixis-GA
# 		:ARG0 (s/signaler)
# 		:ARG1 (l/location)
# 		:ARG2 (a2/actor))
# 	:op2 (i/icon-GA
# 		:ARG0 s
# 		:ARG1 (t/tower)
# 		:ARG2 a2))
# Speech AMR:
#  (i/implicate-predicate-00
# 	:mode imperative
# 	:ARG0 (y/you)
# 	:ARG1 (t/top
# 		:polarity -))
#
# ------------------------------------------------------------------------------------------------------------------------
